# %% [markdown]
# # Machine Learning LAB 3: CLUSTERING - K-means and linkage-based clustering
#
# Course 2023/24: *M. Caligiuri*, *P. Talli*, *F. Lincetto*, *F. Chiariotti*, *P. Zanuttigh*
#
# The notebook contains some simple tasks about **CLUSTERING**.
#
# Complete all the **required code sections** and **answer to all the questions**.
#
# ### IMPORTANT for the evaluation score:
#
# 1. **Read carefully all cells** and **follow the instructions**.
# 2. **Re-run all the code from the beginning** to obtain the results for the final version of your notebook, since this is the way we will do it before evaluating your notebooks.
# 3. Make sure to fill the code in the appropriate places **without modifying the template**, otherwise you risk breaking later cells.
# 4. Please **submit the jupyter notebook file (.ipynb)**, do not submit python scripts (.py) or plain text files. **Make sure that it runs fine with the restat&run all command**.
# 5. **Answer the questions in the appropriate cells**, not in the ones where the question is presented.

# %% [markdown]
# ## Image segmentation with k-means
#
# In this laboratory we will use the k-means algorithm to cluster a dataset of 3D points. We will apply **K-means** to the problem of image compression and image segmentation. The main idea is to apply k-means to the colors of the pixels of an image to select the k most representative colors. Then, we will replace each pixel color with the closest representative color. This will allow us to reduce the number of colors in the image and compress it. A color is a vector of 3 values (R,G,B) that represent the amount of red, green and blue in the color; this implies that each pixel is a point in a 3D space.
#
# In particular you are going to implement the k-means algorithm from scratch and to compare the results with the implementation already present in the sklearn library.
#
# In the second part of the laboratory we will use a **linkage-based** clustering algorithm to cluster a dataset of 2D points and compare it with the results obtained with k-means.
#
# ---

# %% [markdown]
# ## Preliminary step
#
# Place your **name** and **ID number** (matricola) in the cell below. <br>
# Also recall to **save the file as Surname_Name_LAB03.ipynb**, failure to do so will incur in a **lower grade**.

# %% [markdown]
# **Student name**: Alex Pozzobon
#
# **ID Number**: 2071024

# %% [markdown]
# ---

# %% [markdown]
# ## Import all the necessary Python libraries

# %%
# %matplotlib inline  

import numpy as np
import typing as tp
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import KMeans, AgglomerativeClustering
from matplotlib import pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# ## Define the heplper functions
#
# In this section you will find some helper functions (some already implemented, some to be implemented by you) that will be used in the following sections.
# 1. `img_plot` -> function to plot an image with name and dimension as title,
# 2. `scatter_plot` -> function to plot a scatter plot of the data,
# 3. `scatter_plot_2d` -> function to plot a 2D scatter plot of the data,
# 4. `error_plot` -> function to plot the error of the k-means algorithm over the iterations,
# 5. `cluster_plot` -> function to plot the obtained clusters.
#
# **DO NOT CHANGE THE PRE-WRITTEN CODE UNLESS OTHERWISE SPECIFIED**

# %%
def img_plot(img: np.ndarray, title: str = None) -> None:
    """
    Plot an image
    :param img: image to plot
    :param title: title of the plot
    """
    
    plt.figure()
    plt.imshow(img)
    plt.axis('off')
    if title is not None:
        plt.title(f'{title}: {img.shape}')
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
def scatter_plot(data: np.ndarray, clusters: np.ndarray = None, centers: np.ndarray = None, title: str = None) -> None:
    """
    Plot a scatter plot of the data
    :param data: data to plot
    :param clusters: cluster labels
    :param centers: cluster centers
    :param title: title of the plot
    """
    
    fig = plt.figure()
    axis = fig.add_subplot(1, 1, 1, projection="3d")
    axis.set_xlabel("Red")
    axis.set_ylabel("Green")
    axis.set_zlabel("Blue", rotation=90, labelpad=-1)
    if title is not None:
        plt.title(title)
    if clusters is None:
        axis.scatter(data[:,0], data[:,1], data[:,2], marker="o", c=data, s=5)
    else:
        axis.scatter(data[:,0], data[:,1], data[:,2], marker="o", c=clusters, s=1, cmap='viridis', zorder=0, alpha=0.5 )
    if centers is not None:
        axis.scatter(centers[:,0], centers[:,1], centers[:,2], c='red', s=400, zorder=10)
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
def scatter_plot_2d(x: np.ndarray, y: np.ndarray = None, centers: np.ndarray = None, title: str = None) -> None:
    """
    Plot a scatter plot of the data
    :param x: data to plot
    :param y: cluster labels
    :param centers: cluster centers
    :param title: title of the plot
    """

    fig = plt.figure()
    plt.scatter(x[:,0], x[:,1], c=y, marker="o", s=10, cmap='viridis')
    plt.scatter(centers[:,0], centers[:,1], c='black', s=200, alpha=0.5)
    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
def error_plot(errors: np.ndarray, labels: np.ndarray = None) -> None:
    """
    Plot the errors over the iterations
    :param errors: errors to plot
    """
    
    if labels is None:
        plt.plot(errors[1:-1])
        plt.plot(errors[1:-1], 'ro')
    else:
        plt.plot(labels, errors)
        plt.plot(labels, errors, 'ro')
    plt.title('Error over iterations')
    plt.ylabel('Error')
    plt.xlabel('Iteration #')
    plt.grid()
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
def cluster_plot(labels: np.ndarray, x: np.ndarray, title: str = None) -> None:
    """
    Plot the clusters
    :param labels: cluster labels
    :param x: data
    :param title: title of the plot
    """
    
    # Black removed and is used for noise instead.
    unique_labels = set(labels)
    colors = [plt.cm.Spectral(each)
            for each in np.linspace(0, 1, len(unique_labels))]
    for k, col in zip(unique_labels, colors):
        if k == -1:
            # Black used for noise.
            col = [0, 0, 0, 1]

        class_member_mask = (labels == k)

        xy = x[class_member_mask ]
        plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
                markeredgecolor='k', markersize=14)

        xy = x[class_member_mask ]
        plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
                markeredgecolor='k', markersize=6)

    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()
    plt.close()

# %% [markdown]
# ---

# %% [markdown]
# ## A) K-means clustering
#
# ### TO DO (A.0)
#
# **Set** the random **seed** using your **ID**. If you need to change it for testing add a constant explicitly, eg.: 1234567 + 1

# %%
# Fix your ID ("numero di matricola") and the seed for random generator
# as usual you can try different seeds by adding a constant to the number:
# ID = 1234567 + X
ID = 2071024  # insert your ID number here
np.random.seed(ID)

# %% [markdown]
# Load the provided images and display them (if you like you can experiment with other images)

# %%
# To load the images use the function plt.imread(<path_to_iamge>)
path_land = 'data/landscape.jpg'
path_deer = 'data/reindeer.jpg'
path_santa = 'data/santaclaus2.jpg'
land = plt.imread(path_land)
deer = plt.imread(path_deer)
santa = plt.imread(path_santa)

# Plot the images with their shapes
# Sugestion: use the function img_plot()
img_plot(land)
img_plot(deer)
img_plot(santa)

# %% [markdown]
# We are going to start by using the Santa Claus image.

# %%
# Reshape the data to a matrix of num_pixels x 3 
# (divide by 255 to have colors in [0 1] range for plotting functions of sklearn)
santa_num_pixels = santa.shape[0] * santa.shape[1]
santa_r = santa.reshape(santa_num_pixels, 3) / 255.

# Print the shape of the data and the min and max values of the pixels
print("shape : ", santa_r.shape)
print("min   : ", santa_r.min())
print("max   : ", santa_r.max())
# Out:
# shape :  (44032, 3)
# min   :  0.0
# max   :  1.0

# %% [markdown]
# Plot the points in the 3-dimensional space with normalized intervals between 0 and 1 (corresponding to the three channels of the image, i.e. Red Green and Blue)

# %%
# Sugestion: use the function scatter_plot()
scatter_plot(santa_r)

# %% [markdown]
# ### TO DO (A.1)
# Implement the k-means algorithm manually (**do not use the kmeans function of sklearn and do not download implementations from other web sources**). The inputs to the function is the set of vectors to be clustered and the number of clusters. The output must contain the clusters barycenters, a vector associating each data point to the corresponding cluster and the error (value of the cost function) at each iteration.
# Additionally, fix a maximum number of iterations of the k-means algorithm (e.g., 50).
#
# Be careful about the initalization, you can use some random points from the training set, or get random values but ensure they are in the proper range. Poor initalizations can lead to the failure of the algorithm (in particular check that no cluster is initialized as empty, otherwise the algorithm can not update it).

# %%
def my_kmeans(points: np.ndarray, k: int, max_iters: int = 50) -> tp.Tuple[np.ndarray, np.ndarray, list]:
    """
    Perform K-means clustering
    :param points: data points
    :param k: number of clusters
    :param max_iters: maximum number of iterations
    """

    # Generate random centers
    # use sigma and mean to ensure it represent the whole data
    
    mean_points = np.mean(points, axis = 0)
    stdev_points = np.std(points, axis = 0)
    
    #check that centroids are generated within the training set range
    print("means             : ", mean_points)
    print("stdevs/3.         : ", stdev_points)
    print("means - stdevs/3. : ", mean_points - stdev_points / 3.)
    print("means + stdevs/3. : ", mean_points + stdev_points / 3.)
    print("min               : ", np.min(points, axis = 0))
    print("max               : ", np.max(points, axis = 0))
    print("")
    
    dim = (k, points.shape[1])
   
    #different ways to generate centroids: uniform or normal distributions within 1sigma to the mean 
    #or randomly choose k points from points
    
    #UNIFORM
    #mean_points_k = np.full(dim, mean_points)
    #stdev_points_k = np.full(dim, stdev_points / 3.)
    #centroids = mean_points_k + stdev_points_k * np.random.uniform(-1., 1., dim)
    
    #NORMAL
    #centroids = np.random.normal(loc = mean_points, scale = stdev_points, size = dim)
    
    #RANDOM CHOICE
    centeroids_indices = np.random.choice(points.shape[0], k, replace = False)
    centroids = points[centeroids_indices]
  
    prev_error = 100000
    error = [9999]
    
    # Iterate until the estimate of that center stays the same or max iteration are reached
    iters = 0
    while (error[iters] != prev_error) and iters < max_iters:
        # Measure the distance to every center
        centroids_3d = centroids[:, np.newaxis]
        dist = (np.linalg.norm(points - centroids_3d, axis = 2))**2.

        # Assign all training data to closest center
        #ties are broken in np.argmin by taking the position of the first "problematic" element
        clusters = np.argmin(dist, axis = 0)
       
        # Calculate mean for every cluster and update the center
        for i in range(k):
            mask = (clusters == i)
            #make it 3d to broadcast it with points into np.mean
            mask_3d = np.full((points.shape[1], points.shape[0]), mask)
            mask_3d_t = np.transpose(mask_3d)
            centroids[i] = np.mean(points, axis = 0, where = mask_3d_t)
        
        # Update the error
        err = np.sum(np.min(dist, axis = 0))
        error.append(err)
        prev_error = error[iters]
        
        # Update the iteration counter
        iters += 1

    return centroids, clusters, error

# %% [markdown]
# ### TO DO (A.2)
#
# Now try the function you developed on the Santaclaus image with three clusters (k=3).
#
# Then plot the data points in the 3-dimensional space, each point must be coloured based on the membership to one of the clusters. Additionally, plot the respective clusters centroids (use a different shape, size or color to highlight the centroids).

# %%
# Run your K-means function on the data
K=3
santa_mykmeans_centroids, santa_mykmeans_labels, santa_mykmeans_errors = my_kmeans(santa_r, K)

# Print the errors:
print("errors :")
print(santa_mykmeans_errors)
print("")
print("number of iterations : ",len(santa_mykmeans_errors))

# Plot the results
scatter_plot(santa_r, santa_mykmeans_labels, santa_mykmeans_centroids)
# Out:
# means             :  [0.3383916  0.46236106 0.43494375]
# stdevs/3.         :  [0.33257942 0.24715594 0.2522641 ]
# means - stdevs/3. :  [0.22753179 0.37997575 0.35085572]
# means + stdevs/3. :  [0.44925141 0.54474638 0.51903178]
# min               :  [0. 0. 0.]
# max               :  [1. 1. 1.]
#
# errors :
# [9999, 14179.100176855056, 3220.8815948186093, 1130.4565158113535, 1096.465452063881, 1093.3771372026647, 1092.9603524244749, 1092.8907854923184, 1092.8792978369102, 1092.8769044836863, 1092.8766712302174, 1092.876549748246, 1092.876549748246]
#
# number of iterations :  13

# %% [markdown]
# ### TO DO (A.3)
# Plot the value of the error versus the number of iterations

# %%
# Sugestion: use the function error_plot()
error_plot(santa_mykmeans_errors)

# %% [markdown]
# ### TO DO (A.4)
# Now use the k-means function provided in sklearn. Pass to the function the number of clusters and use multiple random initializations (n_init parameter). Go to the documentation page for further details

# %%
# Define the K-means model
kmeans = KMeans(n_clusters = K, init = 'k-means++', n_init = 'auto', max_iter=50)

# Fit the model to the data
kmeans.fit(santa_r)

# Get the cluster centers
santa_kmeans_centroids = kmeans.cluster_centers_

# %% [markdown]
# Perform the same plot as above but with the output of the k-means function provided in sklearn.

# %%
#label the pixels according to the closest center
santa_kmeans_labels = kmeans.labels_
scatter_plot(santa_r, santa_kmeans_labels, santa_kmeans_centroids)

# %% [markdown]
# ### TO DO (A.Q1) [Answare the following]
#
# Compare the results obtained with your implementation and with k-means from sklearn. Do you observe any differences, *i.e.*, do the two plots match?

# %% [markdown]
# **ANSWER A.Q1:** They are very similar so I assume I did the things right

# %% [markdown]
# ### TO DO (A.5)
#
# Now display the segmented image based on the two clusters found above with the k-means functions by sklearn.

# %%
# Extarct the color values of the centers
print("cluster centers sklearn.cluster.KMeans:")
print(santa_kmeans_centroids)
print("")
santa_kmeans_centroids_rgb = (255. * santa_kmeans_centroids).astype(int)
print("cluster centers RGB sklearn.cluster.KMeans:")
print(santa_kmeans_centroids_rgb)
santa_pixel_colors = santa_kmeans_centroids_rgb[santa_kmeans_labels]

# Reshape the data to the original image shape
santa_after_kmeans = santa_pixel_colors.reshape(santa.shape)

# Plot the recolored image
img_plot(santa_after_kmeans, title = 'THE COOLER SANTA CLUSTER')
# Out:
# cluster centers sklearn.cluster.KMeans:
# [[0.07924788 0.39448292 0.34300782]
#  [0.780002   0.7704618  0.76778631]
#  [0.39281483 0.05181739 0.06533731]]
#
# cluster centers RGB sklearn.cluster.KMeans:
# [[ 20 100  87]
#  [198 196 195]
#  [100  13  16]]

# %% [markdown]
# Now display the segmented image based on the two clusters found above with the k-means functions implemented by yourselves.

# %%
# Extarct the color values of the centers
print("cluster centers my_kmeans:")
print(santa_mykmeans_centroids)
print("")
santa_mykmeans_centroids_rgb = (255. * santa_mykmeans_centroids).astype(int)
print("cluster centers RGB my_kmeans:")
print(santa_mykmeans_centroids_rgb)

# Reshape the data to the original image shape
santa_mykmeans_pixel_colors = santa_mykmeans_centroids_rgb[santa_mykmeans_labels]
santa_after_mykmeans = santa_mykmeans_pixel_colors.reshape(santa.shape)

# Plot the recolored image
img_plot(santa_after_mykmeans, title = 'SANTA CLUSTER')
# Out:
# cluster centers my_kmeans:
# [[0.39262661 0.05386229 0.0671155 ]
#  [0.77998175 0.77044226 0.76776639]
#  [0.07859449 0.39470509 0.34315436]]
#
# cluster centers RGB my_kmeans:
# [[100  13  17]
#  [198 196 195]
#  [ 20 100  87]]

# %% [markdown]
# ### TO DO (A.Q2) [Answare the following]
#
# What do you observe? Do you think clustering is useful for image segmenation? And for image compression? Comment your answer.

# %% [markdown]
# **ANSWER A.Q2:** Yes, we were able to "pack" an image into k "clusters", k different colors based on the position of the centers. The algorithm shifts these centers in the color space, depending on their initial positions and on the position of all the points in the dataset, dividing the former into k different clusters. The resulting color (label) of a pixel is based on where it was classified at the end of the algorithm. In this way a very colored and detailed image is compressed into k representative clusters reducing the color space volume. As far as image segmentation, I think that a very detailed image is harder to cluster.

# %% [markdown]
# ### TO DO (A.6)
#
# Now load the landscape image (optional: try also with the reindeer image) and segment it using kmeans with k varying from 2 to 15 clusters. You can use the sklearn implementation.
#
# Then plot the resulting data points in the 3-dimensional space, each point must be colored based on the cluster membership.

# %%
# Reshape the data to a matrix of total_num_pixels x 3
img = land # or deer
img_num_pixels = img.shape[0] * img.shape[1]
img_r = img.reshape(img_num_pixels, 3) / 255.

# Print the shape of the data and the min and max values of the pixels
print("shape : ", img_r.shape)
print("min   : ", img_r.min())
print("max   : ", img_r.max())

# Cycle over different values of K and plot the results for each value
print('\nK-means clustering with different values of K (2-15):')
inertia = list()
for k in range(2,16):
    # Define the K-means model
    img_kmeans = KMeans(n_clusters = k, init = 'k-means++', n_init = 'auto', max_iter=50)

    # Fit the model to the data
    img_kmeans.fit(img_r) 

    # Get the cluster centers
    img_kmeans_centroids = img_kmeans.cluster_centers_

    # Extarct the color values of the centers
    img_kmeans_labels = img_kmeans.labels_
    img_kmeans_centroids_rgb = (255. * img_kmeans_centroids).astype(int)
    img_pixel_colors = img_kmeans_centroids_rgb[img_kmeans_labels]

    # Reshape the data to the original image shape
    img_after_kmeans = img_pixel_colors.reshape(img.shape)

    # Update the inertia
    img_inertia = img_kmeans.inertia_
    inertia.append(img_inertia)
    
    # Plot the scatter plot and the ricolored imag
    scatter_plot(img_r, img_kmeans_labels, img_kmeans_centroids, title = "k=" + str(k))

    # Plot the recolored image
    img_plot(img_after_kmeans, title= "k=" + str(k))
# Out:
# shape :  (19200, 3)
# min   :  0.0
# max   :  1.0
#
# K-means clustering with different values of K (2-15):

# %% [markdown]
# ### TO DO (A.7)
#
# Plot for different values of k (e.g. k between 2 and 15) the respective error of the kmeans algorithm

# %%
error_plot(inertia, labels=range(2,16,1))

# %% [markdown]
# ### TO DO (AQ.3) [Answare the following]
#
# Compare the results with different values of k, what do you observe?
#
# Analyze also the error, which one do you think is the optimal value of k?
#
# Is there a single, clear answer?

# %% [markdown]
# **ANSWER A.Q3:** The error decreases as k increases. Interesting enough, the rate of descent begins to slow down after a k = 5 or 6. Running the algorithm more than 6 times makes it even slower without gaining any particular better results. We can indeed see that at k = 6 and above, the images start to be very similar

# %% [markdown]
# ---

# %% [markdown]
# ## B) Linkage-based clustering
#
# The second part of the assignment concern instead linkage-based clustering. We will use the AgglomerativeClustering module of sklearn.

# %% [markdown]
# ### TO DO (B.0)
#
# Load the sample dataset located at `data/moon_data.npz`

# %%
# Load sample data
moon_path = "data/moon_data.npz"
data = np.load(moon_path)

# Extract data
x = data['X']
labels_true = data['labels_true']

# %% [markdown]
# ### TO DO (B.1)
#
# Now exploit the AgglomerativeClustering algorithm from sklearn on the provided sample data points. Use the "single" linkage type that correspond to the minimum distance criteria seen in the lectures and 2 clusters. Notice that the "single" option has been introduced recently in sklearn, if you get an error ensure you have a recent version of the library. Plot the resulting clustering.

# %%
# Compute Agglomerative Clustering
# Define the Agglomerative Clustering model
agg_clust = AgglomerativeClustering(n_clusters=2, linkage='single', compute_distances=True)

# Fit the model to the data
agg_clust.fit(x)

# Compute the number of clusters in labels, ignoring noise if present.
agg_clust_labels = agg_clust.labels_

# Print the results
n_clust = np.unique(agg_clust_labels).shape[0]
print("Number of clusters : ", n_clust)
print(f"Labels: ", agg_clust_labels)
# Out:
# Number of clusters :  2
# Labels:  [1 0 1 ... 1 0 1]

# %%
# Plot result 
# Sugestion: use the function cluster_plot()
cluster_plot(agg_clust_labels, x)

# %% [markdown]
# ### TO DO (B.2)
#
# Now try the KMeans with two clusters on the same dataset we used for the AgglomerativeClustering algorithm.

# %%
# Define the K-means model
x_kmeans = KMeans(n_clusters=2, n_init="auto")

# Fit the model to the data
x_kmeans.fit(x)

# Get the cluster centers
x_centers = x_kmeans.cluster_centers_

# Extarct the color values of the centers
x_labels = x_kmeans.labels_

# Plot the results
# Sugestion: use the function scatter_plot_2d()
scatter_plot_2d(x, x_labels, x_centers)

# %% [markdown]
# ### TO DO (B.Q1) [Answare the following]
#
# Compare the results of K-means and Agglomerative Clustering and explain what you observe and why?

# %% [markdown]
# **ANSWER B.Q1:** As I explained before the k-means clusters the data depending on their proximity to the a centre which is iteration by iteration updated. In this way the parameter space is divided into k subspaces depending on the euclidean distance between each center. This kind of clustering algorithm works very good for characterizing spherical symmetries however it fails completely in case of other evident distributions like in this case

# %% [markdown]
# ---
